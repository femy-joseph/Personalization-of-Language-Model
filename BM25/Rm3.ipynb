# %%
import json
with open("/content/sample_data/BM25/Lamp4.json","r") as file:
    data=json.load(file)
#json.dumps(data[0]['profile'])

with open("profile.json", "w") as f:
    json.dump(data[0]['profile'], f)

with open("/content/profile.json","r") as file:
    profiles=json.load(file)
profile_texts = []
for i in range(len(profiles)):
  profile_dict = {}
  profile_dict['docno'] = 'doc' + str(i + 1)
  profile_dict['text'] = profiles[i]['text']
  profile_texts.append(profile_dict)

#print(profile_texts)
with open("/content/sample_data/profile_texts.json", "w") as f:
    json.dump(profile_texts, f)

# %%
import pyterrier as pt
import json
pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])

with open("/content/sample_data/profile_texts.json","r") as file:
    profiles=json.load(file)

iter_indexer = pt.IterDictIndexer("/content/Lamp4_index2",meta={'docno': 20, 'text': 4096})
indexref1 = iter_indexer.index(profiles)

index = pt.IndexFactory.of("/content/Lamp4_index2/data.properties")
print(index.getCollectionStatistics())
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
# Number of documents: 17
# Number of terms: 172
# Number of postings: 240
# Number of fields: 1
# Number of tokens: 256
# Field names: [text]
# Positions:   false

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
bm25.transform("Generate a headline for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read")
# Out:
# <ipython-input-13-955c8ce603d1>:2: FutureWarning: .transform() should be passed a dataframe. Use .search() to execute a single query.
#   bm25.transform("Generate a headline for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read")
#    qid  docid  docno  rank     score  \
# 0    1      1   doc2     0  9.835944
# 1    1      4   doc5     1  7.121426
# 2    1      3   doc4     2  5.370766
# 3    1      7   doc8     3  5.018701
# 4    1      9  doc10     4  2.710226
# 5    1     13  doc14     5  2.710226
# 6    1      5   doc6     6  2.393563
# 7    1     14  doc15     7  2.053908
# 8    1     10  doc11     8  1.373133
# 9    1     15  doc16     9  1.254595
# 10   1      8   doc9    10  1.154896
#
#                                                 query
# 0   Generate a headline for the following article ...
# 1   Generate a headline for the following article ...
# 2   Generate a headline for the following article ...
# 3   Generate a headline for the following article ...
# 4   Generate a headline for the following article ...
# 5   Generate a headline for the following article ...
# 6   Generate a headline for the following article ...
# 7   Generate a headline for the following article ...
# 8   Generate a headline for the following article ...
# 9   Generate a headline for the following article ...
# 10  Generate a headline for the following article ...

# %%
import pandas as pd
df = pd.DataFrame(
    [
        ["q1", "Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read"],
        ["q2", "Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared"]
    ], columns=["qid","query"])

bm25.transform(df)
# Out:
#    qid  docid  docno  rank     score  \
# 0   q1      1   doc2     0  9.835944
# 1   q1      4   doc5     1  7.121426
# 2   q1      3   doc4     2  5.370766
# 3   q1      7   doc8     3  5.018701
# 4   q1      9  doc10     4  2.710226
# 5   q1     13  doc14     5  2.710226
# 6   q1      5   doc6     6  2.393563
# 7   q1     14  doc15     7  2.053908
# 8   q1     10  doc11     8  1.373133
# 9   q1     15  doc16     9  1.254595
# 10  q1      8   doc9    10  1.154896
# 11  q2     11  doc12     0  2.454093
# 12  q2     16  doc17     1  2.344867
# 13  q2     14  doc15     2  2.079175
# 14  q2      9  doc10     3  1.284155
# 15  q2     15  doc16     4  1.251501
# 16  q2      1   doc2     5  1.238677
# 17  q2     10  doc11     6  0.726953
# 18  q2      3   doc4     7  0.610775
# 19  q2      7   doc8     8 -0.224612
# 20  q2      8   doc9     9 -0.271830
# 21  q2      4   doc5    10 -0.489756
# 22  q2      0   doc1    11 -0.818178
# 23  q2     13  doc14    12 -0.863949
# 24  q2     12  doc13    13 -1.004421
# 25  q2      2   doc3    14 -1.177036
#
#                                                 query
# 0   Generate,a,headline, for the following article...
# 1   Generate,a,headline, for the following article...
# 2   Generate,a,headline, for the following article...
# 3   Generate,a,headline, for the following article...
# 4   Generate,a,headline, for the following article...
# 5   Generate,a,headline, for the following article...
# 6   Generate,a,headline, for the following article...
# 7   Generate,a,headline, for the following article...
# 8   Generate,a,headline, for the following article...
# 9   Generate,a,headline, for the following article...
# 10  Generate,a,headline, for the following article...
# 11  Generate a headline for the following article ...
# 12  Generate a headline for the following article ...
# 13  Generate a headline for the following article ...
# 14  Generate a headline for the following article ...
# 15  Generate a headline for the following article ...
# 16  Generate a headline for the following article ...
# 17  Generate a headline for the following article ...
# 18  Generate a headline for the following article ...
# 19  Generate a headline for the following article ...
# 20  Generate a headline for the following article ...
# 21  Generate a headline for the following article ...
# 22  Generate a headline for the following article ...
# 23  Generate a headline for the following article ...
# 24  Generate a headline for the following article ...
# 25  Generate a headline for the following article ...

# %%
import re

bm25 = pt.BatchRetrieve(index, wmodel="BM25")
rm3_pipe = bm25 >> pt.rewrite.RM3(index,fb_terms=1, fb_docs=3, fb_lambda=0.6)
rm3_pipe.transform(df)
# Out:
# 02:55:25.611 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 1 among 22 possibilities
# 02:55:25.634 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 4 among 22 possibilities
# 02:55:25.674 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 3 among 20 possibilities
# 02:55:25.682 [main] WARN org.terrier.querying.RM1 - Did not find any useful candidate expansion terms after analysis of 3 feedback documents
# 02:55:25.739 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 11 among 9 possibilities
# 02:55:25.770 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 16 among 11 possibilities
# 02:55:25.776 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 14 among 15 possibilities
# 02:55:25.780 [main] WARN org.terrier.querying.RM1 - Did not find any useful candidate expansion terms after analysis of 3 feedback documents
#   qid  \
# 0  q1
# 1  q2
#
#                                                                                                                                                                                                                                                                                                                         query_0  \
# 0                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read
# 1  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    query
# 0                                                                                                                                                                                                                                                                        applypipeline:off safe^0.031578951 hand^0.031578951 tip^0.031578951 read^0.031578951 internet^0.031578951 here^0.031578951 convers^0.031578951 keep^0.031578951 can^0.031578951
# 1  applypipeline:off safe^0.019354839 well^0.038709678 state^0.019354839 be^0.038709678 parent^0.019354839 sure^0.019354839 law^0.019354839 issu^0.019354839 who^0.019354839 trust^0.019354839 skill^0.019354839 need^0.019354839 children^0.019354839 child^0.019354839 handl^0.019354839 alon^0.038709678 stai^0.019354839 posit^0.019354839 awar^0.019354839 home^0.019354839 prepar^0.000000000 experi^0.019354839 matur^0.019354839 can^0.019354839

# %%
data=[]
new_df = rm3_pipe.transform(df)
for i,q_old in new_df.iterrows():
  qid="q"+str(i+1)
  row=[]
  q=str(q_old['query']).split(" ")
  q=[i for i in q if i!='']


  expanded_query={}

  for i in q:
    regex=r"([a-zA-Z]*)\^((\d+(?:\.\d+)?))"
    try:
      result=re.search(regex,i)
      word=result.group(1)
      score=result.group(2)
      expanded_query[word]= score

    except:
      continue
  #print(expanded_query)

  expand=sorted(expanded_query.items(),key=lambda x:x[1],reverse=True)[:10] #feedback terms 10 to add to query
  add_words=[i[0] for i in expand]
  #print(add_words)
  new_query=q_old['query_0']+' '+' '.join(add_words)
  print(new_query)
  row=[qid,new_query]
  data.append(row)
print(data)
# Out:
# 04:25:14.385 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 1 among 22 possibilities
# 04:25:14.417 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 4 among 22 possibilities
# 04:25:14.446 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 3 among 20 possibilities
# 04:25:14.452 [main] WARN org.terrier.querying.RM1 - Did not find any useful candidate expansion terms after analysis of 3 feedback documents
# 04:25:14.511 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 11 among 9 possibilities
# 04:25:14.542 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 16 among 11 possibilities
# 04:25:14.547 [main] WARN org.terrier.querying.RM1 - Did not identify any usable candidate expansion terms from docid 14 among 15 possibilities
# 04:25:14.551 [main] WARN org.terrier.querying.RM1 - Did not find any useful candidate expansion terms after analysis of 3 feedback documents
# Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# [['q1', 'Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can'], ['q2', 'Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who']]

# %%
expanded_df=pd.DataFrame(data,columns=["qid","query"])
# Out:
#   qid  \
# 0  q1
# 1  q2
#
#                                                                                                                                                                                                                                                                                                                                                                            query
# 0                                                                                              Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 1  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who

# %%
bm25.transform(expanded_df)
# Out:
#    qid  docid  docno  rank     score  \
# 0   q1      1   doc2     0  9.966218
# 1   q1      4   doc5     1  7.121426
# 2   q1      3   doc4     2  5.507281
# 3   q1      7   doc8     3  3.247357
# 4   q1     13  doc14     4  2.710226
# 5   q1      5   doc6     5  2.393563
# 6   q1     14  doc15     6  2.053908
# 7   q1      9  doc10     7  1.434825
# 8   q1     10  doc11     8  1.373133
# 9   q1     15  doc16     9  1.254595
# 10  q1      8   doc9    10  1.154896
# 11  q2     11  doc12     0  3.051068
# 12  q2     16  doc17     1  2.774045
# 13  q2     14  doc15     2  2.153246
# 14  q2      1   doc2     3  1.740871
# 15  q2      9  doc10     4  1.053155
# 16  q2     15  doc16     5  0.851021
# 17  q2      3   doc4     6  0.569399
# 18  q2     10  doc11     7  0.494328
# 19  q2      8   doc9     8 -0.014447
# 20  q2      7   doc8     9 -0.152736
# 21  q2      4   doc5    10 -0.186005
# 22  q2      0   doc1    11 -0.556361
# 23  q2     13  doc14    12 -0.587485
# 24  q2     12  doc13    13 -0.683006
# 25  q2      2   doc3    14 -0.800384
#
#                                                                                                                                                                                                                                                                                                                                                                             query
# 0                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 1                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 2                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 3                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 4                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 5                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 6                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 7                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 8                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 9                                                                                               Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 10                                                                                              Generate,a,headline, for the following article Here are a few tips to keep your teen safe when using the Internet and other web-based technologies If you think its an awkward conversation you can hand them this blog to read safe hand tip read internet here convers keep can
# 11  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 12  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 13  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 14  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 15  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 16  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 17  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 18  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 19  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 20  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 21  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 22  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 23  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 24  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
# 25  Generate a headline for the following article Parents need to be sure their children have the skills and maturity to handle being alone safely as well as be aware of the laws in their state regarding this issue Being trusted to stay home alone can be a positive experience for a child who is mature and well-prepared well be alon safe state parent sure law issu who
